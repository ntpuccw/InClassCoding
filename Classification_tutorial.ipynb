# %% [markdown]
# **<font color=skyblue>機器學習常見的三種監督式分類器（Supervised Classification）</font>**
#
# 分類器（Classifiers）
# - 多元羅吉斯回歸 Multinomial Logistic Regression (LR)
# - 支援向量機 Support Vector Machine (SVM)
# - 類神經網路 artificial Neural Network (ANN)
#
# 分類資料
# - wine.xlsx
# - groups: 13
# - original data vs. principal components
# - split into training data and testing data
#
#
#
# 參考講義：
# https://ntpuccw.blog/sml-lesson-8-%e6%b7%ba%e5%ba%a6%e6%a9%9f%e5%99%a8%e5%ad%b8%e7%bf%92%ef%bc%9a%e5%88%86%e9%a1%9e%e5%99%a8%e7%9a%84%e5%8e%9f%e7%90%86%e8%88%87%e8%a9%95%e6%af%94%e5%af%a6%e9%a9%97/
# <hr>

# %% [markdown]
# <font color=yellow>Import Basic Packages</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# <font color=yellow>資料準備</font>

# %%
# Read data
df = pd.read_excel('data/Wine.xlsx')
X = np.array(df.iloc[:, :-1]) # 排除最後一欄標籤 N x p
y = np.array(df.iloc[:, -1]) # label N x 1

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30)

# Standardize data
scaler = StandardScaler()
X_train_ = scaler.fit_transform(X_train)
X_test_ = scaler.transform(X_test)

# print training and testing data shapes
print("Training data shape:", X_train_.shape)
print("Testing data shape:", X_test_.shape)
# Out:
# Training data shape: (124, 13)
# Testing data shape: (54, 13)

# %% [markdown]
# <font color=yellow>LogisticRegression on original data</font>
#
# - 了解 LogisticRegression 的重要參數對結果的影響，譬如 C：Inverse of regularization strength。
# - 嘗試不同的演算法 solvers：{‘lbfgs’, ‘liblinear’, ‘newton-cg’, ‘newton-cholesky’, ‘sag’, ‘saga’}.
# - 了解對評估分群能力的指標： precision, recall, f1-score
#
# precision = $\frac{TP}{TP+FP}$,
# recall = $\frac{TP}{TP+FN}$,
# F1-score = $2\frac{precision\cdot recall}{precision + recall}$

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

opts = dict(C=1.0, tol = 1e-6, max_iter = int(1e6), verbose=1)
solver = 'lbfgs'  # 'lbfgs' is the default
# solver = 'liblinear'
# solver = 'newton-cg'
# clf_original = LogisticRegression(solver = 'lbfgs', tol = 1e-6, max_iter = int(1e6), verbose=True)
clf_LR_original = LogisticRegression(solver = solver, **opts)
clf_LR_original.fit(X_train_, y_train) # input data must be (n_samples x n_features)
y_pred = clf_LR_original.predict(X_test_) # predict class labels for samples in X_test_
# print training score
print(f"Training score = {accuracy_score(y_train, clf_LR_original.predict(X_train_)):.2%}\n")
# print testing score
print(f"Testing score = {accuracy_score(y_test, y_pred):.2%}\n")
print(f"Testing score = {clf_LR_original.score(X_test_, y_test):.2%}\n")
print("Classification report: Original data\n")
print(classification_report(y_test, y_pred))
# Out:
# Training score = 100.00%
#
# Testing score = 98.15%
#
# Testing score = 98.15%
#
# Classification report: Original data
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        24
#            2       1.00      0.94      0.97        17
#            3       0.93      1.00      0.96        13
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %% [markdown]
# <font color=yellow>LogisticRegression on principal components</font>

# %%
from sklearn.decomposition import PCA

q = 2
pca = PCA(n_components = q).fit(X_train_)
Z_train = pca.transform(X_train_)
Z_test = pca.transform(X_test_)
opts = dict(tol = 1e-6, max_iter = int(1e6), verbose=1)
solver = 'lbfgs'  # 'lbfgs' is default; 
# solver = 'liblinear'
# solver = 'newton-cg'
# clf_LR = LogisticRegression(solver = 'lbfgs', tol = 1e-6, max_iter = int(1e6), verbose=1)
clf_PCA = LogisticRegression(solver = solver, **opts)
clf_PCA.fit(Z_train, y_train) # input data must be (n_samples x n_features)
y_pred = clf_PCA.predict(Z_test)

print(f"Training score: {accuracy_score(y_train, clf_PCA.predict(Z_train)):.2%}\n")
# print testing score
print(f"Testing score: {clf_PCA.score(Z_test, y_test):.2%}\n")
print(f"Classification report: PCA with {q} components\n")
print(classification_report(y_test, y_pred))
# Out:
# Training score: 95.97%
#
# Testing score: 96.30%
#
# Classification report: PCA with 2 components
#
#               precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96        24
#            2       0.94      0.94      0.94        17
#            3       1.00      1.00      1.00        13
#
#     accuracy                           0.96        54
#    macro avg       0.97      0.97      0.97        54
# weighted avg       0.96      0.96      0.96        54

# %% [markdown]
# <hr>
# <font color=orange>練習：製作副程式以方便比較 original data vs principal components 的測試結果。譬如，將結果安排在同一個表格。
# <hr>

# %% [markdown]
# <font color=yellow>Use LogisticRegressionCV: Logistic Regression + Cross Validation</font>
#
# - Cross Validation: performs cross‑validated hyperparameter tuning over Cs and l1_ratios and then refits the best model.
# - Cs: the inverse of regularization strength.
# - li_ratio: mixing parameter between L1 and L2 penalties.

# %%
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import accuracy_score

opts = dict(l1_ratios=(0,), tol = 1e-6, max_iter = int(1e6), verbose=1,\
            use_legacy_attributes=True) # use_legacy_attributes=True is needed to avoid FutureWarning: The attribute `C_` is deprecated in favor of `Cs_` and will be removed in v1.3. To access the best C value, use `clf_originalCV.Cs_[0]` instead of `clf_originalCV.C_[0]`.
solver = 'lbfgs'  # 'lbfgs' is the default
# solver = 'liblinear'
# solver = 'newton-cg'
Cs = np.logspace(-4, 4, 20) # Cs = np.logspace(-5, 5, 20) --- IGNORE ---
clf_originalCV = LogisticRegressionCV(solver = solver, Cs = Cs, **opts)
clf_originalCV.fit(X_train_, y_train) # input data must be (n_samples x n_features)
y_pred = clf_originalCV.predict(X_test_)
# print training score
print(f"Training score = {accuracy_score(y_train, clf_originalCV.predict(X_train_)):.2%}\n")
# print testing score
print(f"Testing score = {accuracy_score(y_test, y_pred):.2%}\n")
print(f"Testing score = {clf_originalCV.score(X_test_, y_test):.2%}\n")
print("Classification report: Original data with CV\n")
print(classification_report(y_test, y_pred))
# print the best C value found by CV
print(f"Best C value found by CV: {clf_originalCV.C_[0]:.4f}\n")
# print the best l1_ratio value found by CV
print(f"Best l1_ratio value found by CV: {clf_originalCV.l1_ratio_[0]:.4f}\n")
# Out:
# Training score = 100.00%
#
# Testing score = 98.15%
#
# Testing score = 98.15%
#
# Classification report: Original data with CV
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        24
#            2       1.00      0.94      0.97        17
#            3       0.93      1.00      0.96        13
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54
#
# Best C value found by CV: 11.2884
#
# Best l1_ratio value found by CV: 0.0000
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished

# %% [markdown]
# <hr>
# <font color=yellow>SVM on original data</font>
#
# - 了解 SVC 的重要參數對結果的影響，譬如
#     - C：the inverse of the regularization strength。
#     - decision function shape: ovr (one vs rest), ovo (one vs one)
# - 嘗試不同的核 kernel: linear, poly, rbf, sigmoid, precomputed

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import classification_report

C = 1 # SVM regularization parameter
opts = dict(C = C, tol = 1e-6, max_iter = int(1e6), \
            decision_function_shape = 'ovo', verbose=1)

clf_svm = SVC(kernel='linear', **opts)
# clf_svm = SVC(kernel='rbf', gamma=0.2, **opts)
# clf_svm = SVC(kernel='poly', degree=3, gamma='auto', **opts)
# clf_svm = LinearSVC(**opts) # one vs the rest
clf_svm.fit(X_train_, y_train)
predictions = clf_svm.predict(X_test_)
print(classification_report(y_test, predictions))
# Out:
# [LibSVM]              precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        17
#            2       1.00      0.95      0.98        21
#            3       0.94      1.00      0.97        16
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %% [markdown]
# <hr>
# <font color=yellow>ANN on original data</font>
#
# 關注參數的選擇：
# - 隱藏層 hidden_layers
# - 激活函數 activation function: identity, logistic, tanh, relu (default)
# - 演算法 solvers: lbfgs, sgd, adam (default)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# hidden_layers = (512,) # one hidden layer
# activation = 'relu' # the default
hidden_layers = (20,) # one hidden layer
activation = 'logistic' # the default
opts = dict(hidden_layer_sizes = hidden_layers, verbose = True, \
        activation = activation, tol = 1e-6, max_iter = int(1e6))
# solver = 'sgd' # not efficient, need more tuning
# solver = 'lbfgs' # not suitable here
solver = 'adam' # default solver
clf_MLP = MLPClassifier(solver = solver, **opts) 
clf_MLP.fit(X_train_, y_train)
predictions = clf_MLP.predict(X_test_)
# print("accuracy for tested data: {:.2f}%".format(100*np.mean(y_test_hat == y_test)))
print("accuracy for test data: {:.2f}%".format(100*clf_MLP.score(X_test, y_test)))
print(classification_report(y_test, predictions))
# Out:
# Iteration 1, loss = 1.11558555
# Iteration 2, loss = 1.11058505
# Iteration 3, loss = 1.10567096
# Iteration 4, loss = 1.10084323
# Iteration 5, loss = 1.09609969
# Iteration 6, loss = 1.09143495
# Iteration 7, loss = 1.08684200
# Iteration 8, loss = 1.08231469
# Iteration 9, loss = 1.07784809
# Iteration 10, loss = 1.07343778
# Iteration 11, loss = 1.06907954
# Iteration 12, loss = 1.06476931
# Iteration 13, loss = 1.06050327
# Iteration 14, loss = 1.05627791
# Iteration 15, loss = 1.05208996
# Iteration 16, loss = 1.04793643
# Iteration 17, loss = 1.04381452
# Iteration 18, loss = 1.03972160
# Iteration 19, loss = 1.03565522
# Iteration 20, loss = 1.03161305
# Iteration 21, loss = 1.02759289
# Iteration 22, loss = 1.02359265
# Iteration 23, loss = 1.01961033
# Iteration 24, loss = 1.01564402
# Iteration 25, loss = 1.01169187
# Iteration 26, loss = 1.00775214
# Iteration 27, loss = 1.00382313
# Iteration 28, loss = 0.99990320
# Iteration 29, loss = 0.99599079
# Iteration 30, loss = 0.99208444
# Iteration 31, loss = 0.98818273
# Iteration 32, loss = 0.98428435
# Iteration 33, loss = 0.98038806
# Iteration 34, loss = 0.97649275
# Iteration 35, loss = 0.97259737
# Iteration 36, loss = 0.96870098
# Iteration 37, loss = 0.96480272
# Iteration 38, loss = 0.96090182
# Iteration 39, loss = 0.95699758
# Iteration 40, loss = 0.95308938
# Iteration 41, loss = 0.94917663
# Iteration 42, loss = 0.94525884
# Iteration 43, loss = 0.94133555
# Iteration 44, loss = 0.93740637
# Iteration 45, loss = 0.93347093
# Iteration 46, loss = 0.92952893
# Iteration 47, loss = 0.92558009
# Iteration 48, loss = 0.92162417
# Iteration 49, loss = 0.91766099
# Iteration 50, loss = 0.91369036
# Iteration 51, loss = 0.90971216
# Iteration 52, loss = 0.90572629
# Iteration 53, loss = 0.90173267
# Iteration 54, loss = 0.89773127
# Iteration 55, loss = 0.89372207
# Iteration 56, loss = 0.88970510
# Iteration 57, loss = 0.88568039
# Iteration 58, loss = 0.88164803
# Iteration 59, loss = 0.87760812
# Iteration 60, loss = 0.87356078
# Iteration 61, loss = 0.86950618
# Iteration 62, loss = 0.86544448
# Iteration 63, loss = 0.86137589
# Iteration 64, loss = 0.85730064
# Iteration 65, loss = 0.85321897
# Iteration 66, loss = 0.84913114
# Iteration 67, loss = 0.84503743
# Iteration 68, loss = 0.84093816
# Iteration 69, loss = 0.83683363
# Iteration 70, loss = 0.83272418
# Iteration 71, loss = 0.82861016
# Iteration 72, loss = 0.82449193
# Iteration 73, loss = 0.82036987
# Iteration 74, loss = 0.81624437
# Iteration 75, loss = 0.81211582
# Iteration 76, loss = 0.80798463
# Iteration 77, loss = 0.80385123
# Iteration 78, loss = 0.79971605
# Iteration 79, loss = 0.79557952
# Iteration 80, loss = 0.79144208
# Iteration 81, loss = 0.78730419
# Iteration 82, loss = 0.78316631
# Iteration 83, loss = 0.77902889
# Iteration 84, loss = 0.77489241
# Iteration 85, loss = 0.77075733
# Iteration 86, loss = 0.76662413
# Iteration 87, loss = 0.76249328
# Iteration 88, loss = 0.75836525
# Iteration 89, loss = 0.75424053
# Iteration 90, loss = 0.75011960
# Iteration 91, loss = 0.74600292
# Iteration 92, loss = 0.74189098
# Iteration 93, loss = 0.73778425
# Iteration 94, loss = 0.73368321
# Iteration 95, loss = 0.72958832
# Iteration 96, loss = 0.72550005
# Iteration 97, loss = 0.72141888
# Iteration 98, loss = 0.71734525
# Iteration 99, loss = 0.71327962
# Iteration 100, loss = 0.70922246
# Iteration 101, loss = 0.70517420
# Iteration 102, loss = 0.70113530
# Iteration 103, loss = 0.69710619
# Iteration 104, loss = 0.69308730
# Iteration 105, loss = 0.68907906
# Iteration 106, loss = 0.68508189
# Iteration 107, loss = 0.68109622
# Iteration 108, loss = 0.67712244
# Iteration 109, loss = 0.67316096
# Iteration 110, loss = 0.66921219
# Iteration 111, loss = 0.66527650
# Iteration 112, loss = 0.66135428
# Iteration 113, loss = 0.65744590
# Iteration 114, loss = 0.65355174
# Iteration 115, loss = 0.64967214
# Iteration 116, loss = 0.64580746
# Iteration 117, loss = 0.64195803
# Iteration 118, loss = 0.63812420
# Iteration 119, loss = 0.63430629
# Iteration 120, loss = 0.63050461
# Iteration 121, loss = 0.62671946
# Iteration 122, loss = 0.62295114
# Iteration 123, loss = 0.61919994
# Iteration 124, loss = 0.61546613
# Iteration 125, loss = 0.61174998
# Iteration 126, loss = 0.60805175
# Iteration 127, loss = 0.60437168
# Iteration 128, loss = 0.60071000
# Iteration 129, loss = 0.59706695
# Iteration 130, loss = 0.59344273
# Iteration 131, loss = 0.58983756
# Iteration 132, loss = 0.58625162
# Iteration 133, loss = 0.58268511
# Iteration 134, loss = 0.57913820
# Iteration 135, loss = 0.57561106
# Iteration 136, loss = 0.57210383
# Iteration 137, loss = 0.56861667
# Iteration 138, loss = 0.56514971
# Iteration 139, loss = 0.56170308
# Iteration 140, loss = 0.55827690
# Iteration 141, loss = 0.55487127
# Iteration 142, loss = 0.55148630
# Iteration 143, loss = 0.54812207
# Iteration 144, loss = 0.54477866
# Iteration 145, loss = 0.54145616
# Iteration 146, loss = 0.53815462
# Iteration 147, loss = 0.53487410
# Iteration 148, loss = 0.53161465
# Iteration 149, loss = 0.52837631
# Iteration 150, loss = 0.52515911
# Iteration 151, loss = 0.52196309
# Iteration 152, loss = 0.51878826
# Iteration 153, loss = 0.51563463
# Iteration 154, loss = 0.51250221
# Iteration 155, loss = 0.50939100
# Iteration 156, loss = 0.50630100
# Iteration 157, loss = 0.50323218
# Iteration 158, loss = 0.50018453
# Iteration 159, loss = 0.49715803
# Iteration 160, loss = 0.49415264
# Iteration 161, loss = 0.49116833
# Iteration 162, loss = 0.48820506
# Iteration 163, loss = 0.48526279
# Iteration 164, loss = 0.48234146
# Iteration 165, loss = 0.47944103
# Iteration 166, loss = 0.47656142
# Iteration 167, loss = 0.47370258
# Iteration 168, loss = 0.47086444
# Iteration 169, loss = 0.46804693
# Iteration 170, loss = 0.46524998
# Iteration 171, loss = 0.46247351
# Iteration 172, loss = 0.45971743
# Iteration 173, loss = 0.45698166
# Iteration 174, loss = 0.45426611
# Iteration 175, loss = 0.45157070
# Iteration 176, loss = 0.44889533
# Iteration 177, loss = 0.44623990
# Iteration 178, loss = 0.44360431
# Iteration 179, loss = 0.44098847
# Iteration 180, loss = 0.43839227
# Iteration 181, loss = 0.43581560
# Iteration 182, loss = 0.43325836
# Iteration 183, loss = 0.43072044
# Iteration 184, loss = 0.42820173
# Iteration 185, loss = 0.42570212
# Iteration 186, loss = 0.42322148
# Iteration 187, loss = 0.42075971
# Iteration 188, loss = 0.41831668
# Iteration 189, loss = 0.41589229
# Iteration 190, loss = 0.41348640
# Iteration 191, loss = 0.41109891
# Iteration 192, loss = 0.40872968
# Iteration 193, loss = 0.40637860
# Iteration 194, loss = 0.40404554
# Iteration 195, loss = 0.40173037
# Iteration 196, loss = 0.39943298
# Iteration 197, loss = 0.39715323
# Iteration 198, loss = 0.39489101
# Iteration 199, loss = 0.39264618
# Iteration 200, loss = 0.39041861
# Iteration 201, loss = 0.38820819
# Iteration 202, loss = 0.38601477
# Iteration 203, loss = 0.38383824
# Iteration 204, loss = 0.38167846
# Iteration 205, loss = 0.37953531
# Iteration 206, loss = 0.37740866
# Iteration 207, loss = 0.37529837
# Iteration 208, loss = 0.37320433
# Iteration 209, loss = 0.37112639
# Iteration 210, loss = 0.36906444
# Iteration 211, loss = 0.36701835
# Iteration 212, loss = 0.36498798
# Iteration 213, loss = 0.36297321
# Iteration 214, loss = 0.36097390
# Iteration 215, loss = 0.35898994
# Iteration 216, loss = 0.35702120
# Iteration 217, loss = 0.35506754
# Iteration 218, loss = 0.35312885
# Iteration 219, loss = 0.35120499
# Iteration 220, loss = 0.34929584
# Iteration 221, loss = 0.34740127
# Iteration 222, loss = 0.34552116
# Iteration 223, loss = 0.34365539
# Iteration 224, loss = 0.34180383
# Iteration 225, loss = 0.33996635
# Iteration 226, loss = 0.33814283
# Iteration 227, loss = 0.33633316
# Iteration 228, loss = 0.33453721
# Iteration 229, loss = 0.33275486
# Iteration 230, loss = 0.33098598
# Iteration 231, loss = 0.32923047
# Iteration 232, loss = 0.32748819
# Iteration 233, loss = 0.32575903
# Iteration 234, loss = 0.32404288
# Iteration 235, loss = 0.32233961
# Iteration 236, loss = 0.32064911
# Iteration 237, loss = 0.31897127
# Iteration 238, loss = 0.31730596
# Iteration 239, loss = 0.31565308
# Iteration 240, loss = 0.31401252
# Iteration 241, loss = 0.31238415
# Iteration 242, loss = 0.31076787
# Iteration 243, loss = 0.30916356
# Iteration 244, loss = 0.30757112
# Iteration 245, loss = 0.30599044
# Iteration 246, loss = 0.30442141
# Iteration 247, loss = 0.30286392
# Iteration 248, loss = 0.30131786
# Iteration 249, loss = 0.29978313
# Iteration 250, loss = 0.29825963
# Iteration 251, loss = 0.29674724
# Iteration 252, loss = 0.29524587
# Iteration 253, loss = 0.29375541
# Iteration 254, loss = 0.29227576
# Iteration 255, loss = 0.29080682
# Iteration 256, loss = 0.28934849
# Iteration 257, loss = 0.28790067
# Iteration 258, loss = 0.28646326
# Iteration 259, loss = 0.28503617
# Iteration 260, loss = 0.28361929
# Iteration 261, loss = 0.28221254
# Iteration 262, loss = 0.28081582
# Iteration 263, loss = 0.27942903
# Iteration 264, loss = 0.27805208
# Iteration 265, loss = 0.27668488
# Iteration 266, loss = 0.27532733
# Iteration 267, loss = 0.27397935
# Iteration 268, loss = 0.27264085
# Iteration 269, loss = 0.27131174
# Iteration 270, loss = 0.26999192
# Iteration 271, loss = 0.26868132
# Iteration 272, loss = 0.26737985
# Iteration 273, loss = 0.26608741
# Iteration 274, loss = 0.26480394
# Iteration 275, loss = 0.26352933
# Iteration 276, loss = 0.26226352
# Iteration 277, loss = 0.26100642
# Iteration 278, loss = 0.25975794
# Iteration 279, loss = 0.25851801
# Iteration 280, loss = 0.25728654
# Iteration 281, loss = 0.25606347
# Iteration 282, loss = 0.25484871
# Iteration 283, loss = 0.25364218
# Iteration 284, loss = 0.25244380
# Iteration 285, loss = 0.25125351
# Iteration 286, loss = 0.25007123
# Iteration 287, loss = 0.24889688
# Iteration 288, loss = 0.24773039
# Iteration 289, loss = 0.24657169
# Iteration 290, loss = 0.24542071
# Iteration 291, loss = 0.24427737
# Iteration 292, loss = 0.24314161
# Iteration 293, loss = 0.24201336
# Iteration 294, loss = 0.24089254
# Iteration 295, loss = 0.23977910
# Iteration 296, loss = 0.23867296
# Iteration 297, loss = 0.23757406
# Iteration 298, loss = 0.23648233
# Iteration 299, loss = 0.23539771
# Iteration 300, loss = 0.23432013
# Iteration 301, loss = 0.23324953
# Iteration 302, loss = 0.23218585
# Iteration 303, loss = 0.23112903
# Iteration 304, loss = 0.23007901
# Iteration 305, loss = 0.22903571
# Iteration 306, loss = 0.22799910
# Iteration 307, loss = 0.22696910
# Iteration 308, loss = 0.22594565
# Iteration 309, loss = 0.22492871
# Iteration 310, loss = 0.22391821
# Iteration 311, loss = 0.22291409
# Iteration 312, loss = 0.22191631
# Iteration 313, loss = 0.22092480
# Iteration 314, loss = 0.21993951
# Iteration 315, loss = 0.21896039
# Iteration 316, loss = 0.21798739
# Iteration 317, loss = 0.21702044
# Iteration 318, loss = 0.21605950
# Iteration 319, loss = 0.21510453
# Iteration 320, loss = 0.21415545
# Iteration 321, loss = 0.21321224
# Iteration 322, loss = 0.21227483
# Iteration 323, loss = 0.21134318
# Iteration 324, loss = 0.21041724
# Iteration 325, loss = 0.20949697
# Iteration 326, loss = 0.20858230
# Iteration 327, loss = 0.20767321
# Iteration 328, loss = 0.20676963
# Iteration 329, loss = 0.20587153
# Iteration 330, loss = 0.20497886
# Iteration 331, loss = 0.20409158
# Iteration 332, loss = 0.20320964
# Iteration 333, loss = 0.20233300
# Iteration 334, loss = 0.20146161
# Iteration 335, loss = 0.20059544
# Iteration 336, loss = 0.19973443
# Iteration 337, loss = 0.19887856
# Iteration 338, loss = 0.19802777
# Iteration 339, loss = 0.19718203
# Iteration 340, loss = 0.19634129
# Iteration 341, loss = 0.19550553
# Iteration 342, loss = 0.19467469
# Iteration 343, loss = 0.19384874
# Iteration 344, loss = 0.19302764
# Iteration 345, loss = 0.19221135
# Iteration 346, loss = 0.19139984
# Iteration 347, loss = 0.19059307
# Iteration 348, loss = 0.18979100
# Iteration 349, loss = 0.18899360
# Iteration 350, loss = 0.18820083
# Iteration 351, loss = 0.18741265
# Iteration 352, loss = 0.18662904
# Iteration 353, loss = 0.18584995
# Iteration 354, loss = 0.18507535
# Iteration 355, loss = 0.18430521
# Iteration 356, loss = 0.18353949
# Iteration 357, loss = 0.18277816
# Iteration 358, loss = 0.18202120
# Iteration 359, loss = 0.18126856
# Iteration 360, loss = 0.18052021
# Iteration 361, loss = 0.17977613
# Iteration 362, loss = 0.17903629
# Iteration 363, loss = 0.17830064
# Iteration 364, loss = 0.17756917
# Iteration 365, loss = 0.17684183
# Iteration 366, loss = 0.17611861
# Iteration 367, loss = 0.17539947
# Iteration 368, loss = 0.17468439
# Iteration 369, loss = 0.17397333
# Iteration 370, loss = 0.17326626
# Iteration 371, loss = 0.17256316
# Iteration 372, loss = 0.17186400
# Iteration 373, loss = 0.17116876
# Iteration 374, loss = 0.17047740
# Iteration 375, loss = 0.16978990
# Iteration 376, loss = 0.16910623
# Iteration 377, loss = 0.16842636
# Iteration 378, loss = 0.16775028
# Iteration 379, loss = 0.16707795
# Iteration 380, loss = 0.16640934
# Iteration 381, loss = 0.16574444
# Iteration 382, loss = 0.16508322
# Iteration 383, loss = 0.16442565
# Iteration 384, loss = 0.16377170
# Iteration 385, loss = 0.16312137
# Iteration 386, loss = 0.16247461
# Iteration 387, loss = 0.16183141
# Iteration 388, loss = 0.16119174
# Iteration 389, loss = 0.16055558
# Iteration 390, loss = 0.15992291
# Iteration 391, loss = 0.15929370
# Iteration 392, loss = 0.15866793
# Iteration 393, loss = 0.15804558
# Iteration 394, loss = 0.15742663
# Iteration 395, loss = 0.15681105
# Iteration 396, loss = 0.15619883
# Iteration 397, loss = 0.15558993
# Iteration 398, loss = 0.15498435
# Iteration 399, loss = 0.15438205
# Iteration 400, loss = 0.15378303
# Iteration 401, loss = 0.15318724
# Iteration 402, loss = 0.15259469
# Iteration 403, loss = 0.15200534
# Iteration 404, loss = 0.15141918
# Iteration 405, loss = 0.15083618
# Iteration 406, loss = 0.15025633
# Iteration 407, loss = 0.14967960
# Iteration 408, loss = 0.14910598
# Iteration 409, loss = 0.14853545
# Iteration 410, loss = 0.14796798
# Iteration 411, loss = 0.14740357
# Iteration 412, loss = 0.14684218
# Iteration 413, loss = 0.14628380
# Iteration 414, loss = 0.14572842
# Iteration 415, loss = 0.14517601
# Iteration 416, loss = 0.14462655
# Iteration 417, loss = 0.14408004
# Iteration 418, loss = 0.14353644
# Iteration 419, loss = 0.14299574
# Iteration 420, loss = 0.14245792
# Iteration 421, loss = 0.14192297
# Iteration 422, loss = 0.14139087
# Iteration 423, loss = 0.14086160
# Iteration 424, loss = 0.14033514
# Iteration 425, loss = 0.13981148
# Iteration 426, loss = 0.13929060
# Iteration 427, loss = 0.13877248
# Iteration 428, loss = 0.13825710
# Iteration 429, loss = 0.13774445
# Iteration 430, loss = 0.13723451
# Iteration 431, loss = 0.13672727
# Iteration 432, loss = 0.13622271
# Iteration 433, loss = 0.13572081
# Iteration 434, loss = 0.13522156
# Iteration 435, loss = 0.13472493
# Iteration 436, loss = 0.13423092
# Iteration 437, loss = 0.13373951
# Iteration 438, loss = 0.13325068
# Iteration 439, loss = 0.13276442
# Iteration 440, loss = 0.13228070
# Iteration 441, loss = 0.13179953
# Iteration 442, loss = 0.13132087
# Iteration 443, loss = 0.13084471
# Iteration 444, loss = 0.13037105
# Iteration 445, loss = 0.12989986
# Iteration 446, loss = 0.12943113
# Iteration 447, loss = 0.12896484
# Iteration 448, loss = 0.12850099
# Iteration 449, loss = 0.12803954
# Iteration 450, loss = 0.12758050
# Iteration 451, loss = 0.12712384
# Iteration 452, loss = 0.12666955
# Iteration 453, loss = 0.12621762
# Iteration 454, loss = 0.12576802
# Iteration 455, loss = 0.12532076
# Iteration 456, loss = 0.12487580
# Iteration 457, loss = 0.12443315
# Iteration 458, loss = 0.12399278
# Iteration 459, loss = 0.12355468
# Iteration 460, loss = 0.12311883
# Iteration 461, loss = 0.12268523
# Iteration 462, loss = 0.12225386
# Iteration 463, loss = 0.12182470
# Iteration 464, loss = 0.12139774
# Iteration 465, loss = 0.12097297
# Iteration 466, loss = 0.12055037
# Iteration 467, loss = 0.12012994
# Iteration 468, loss = 0.11971165
# Iteration 469, loss = 0.11929549
# Iteration 470, loss = 0.11888146
# Iteration 471, loss = 0.11846953
# Iteration 472, loss = 0.11805970
# Iteration 473, loss = 0.11765195
# Iteration 474, loss = 0.11724626
# Iteration 475, loss = 0.11684263
# Iteration 476, loss = 0.11644105
# Iteration 477, loss = 0.11604149
# Iteration 478, loss = 0.11564396
# Iteration 479, loss = 0.11524842
# Iteration 480, loss = 0.11485488
# Iteration 481, loss = 0.11446332
# Iteration 482, loss = 0.11407373
# Iteration 483, loss = 0.11368609
# Iteration 484, loss = 0.11330040
# Iteration 485, loss = 0.11291663
# Iteration 486, loss = 0.11253479
# Iteration 487, loss = 0.11215485
# Iteration 488, loss = 0.11177680
# Iteration 489, loss = 0.11140064
# Iteration 490, loss = 0.11102635
# Iteration 491, loss = 0.11065392
# Iteration 492, loss = 0.11028334
# Iteration 493, loss = 0.10991459
# Iteration 494, loss = 0.10954767
# Iteration 495, loss = 0.10918256
# Iteration 496, loss = 0.10881925
# Iteration 497, loss = 0.10845773
# Iteration 498, loss = 0.10809800
# Iteration 499, loss = 0.10774003
# Iteration 500, loss = 0.10738381
# Iteration 501, loss = 0.10702935
# Iteration 502, loss = 0.10667661
# Iteration 503, loss = 0.10632561
# Iteration 504, loss = 0.10597631
# Iteration 505, loss = 0.10562872
# Iteration 506, loss = 0.10528282
# Iteration 507, loss = 0.10493860
# Iteration 508, loss = 0.10459605
# Iteration 509, loss = 0.10425517
# Iteration 510, loss = 0.10391593
# Iteration 511, loss = 0.10357833
# Iteration 512, loss = 0.10324236
# Iteration 513, loss = 0.10290801
# Iteration 514, loss = 0.10257527
# Iteration 515, loss = 0.10224412
# Iteration 516, loss = 0.10191457
# Iteration 517, loss = 0.10158659
# Iteration 518, loss = 0.10126019
# Iteration 519, loss = 0.10093534
# Iteration 520, loss = 0.10061204
# Iteration 521, loss = 0.10029028
# Iteration 522, loss = 0.09997005
# Iteration 523, loss = 0.09965134
# Iteration 524, loss = 0.09933415
# Iteration 525, loss = 0.09901845
# Iteration 526, loss = 0.09870425
# Iteration 527, loss = 0.09839153
# Iteration 528, loss = 0.09808028
# Iteration 529, loss = 0.09777050
# Iteration 530, loss = 0.09746217
# Iteration 531, loss = 0.09715529
# Iteration 532, loss = 0.09684985
# Iteration 533, loss = 0.09654584
# Iteration 534, loss = 0.09624324
# Iteration 535, loss = 0.09594206
# Iteration 536, loss = 0.09564228
# Iteration 537, loss = 0.09534389
# Iteration 538, loss = 0.09504689
# Iteration 539, loss = 0.09475126
# Iteration 540, loss = 0.09445700
# Iteration 541, loss = 0.09416411
# Iteration 542, loss = 0.09387256
# Iteration 543, loss = 0.09358235
# Iteration 544, loss = 0.09329348
# Iteration 545, loss = 0.09300594
# Iteration 546, loss = 0.09271972
# Iteration 547, loss = 0.09243480
# Iteration 548, loss = 0.09215119
# Iteration 549, loss = 0.09186887
# Iteration 550, loss = 0.09158784
# Iteration 551, loss = 0.09130809
# Iteration 552, loss = 0.09102961
# Iteration 553, loss = 0.09075239
# Iteration 554, loss = 0.09047642
# Iteration 555, loss = 0.09020171
# Iteration 556, loss = 0.08992823
# Iteration 557, loss = 0.08965599
# Iteration 558, loss = 0.08938497
# Iteration 559, loss = 0.08911517
# Iteration 560, loss = 0.08884658
# Iteration 561, loss = 0.08857920
# Iteration 562, loss = 0.08831301
# Iteration 563, loss = 0.08804801
# Iteration 564, loss = 0.08778419
# Iteration 565, loss = 0.08752155
# Iteration 566, loss = 0.08726007
# Iteration 567, loss = 0.08699975
# Iteration 568, loss = 0.08674059
# Iteration 569, loss = 0.08648258
# Iteration 570, loss = 0.08622570
# Iteration 571, loss = 0.08596996
# Iteration 572, loss = 0.08571534
# Iteration 573, loss = 0.08546185
# Iteration 574, loss = 0.08520946
# Iteration 575, loss = 0.08495819
# Iteration 576, loss = 0.08470801
# Iteration 577, loss = 0.08445893
# Iteration 578, loss = 0.08421094
# Iteration 579, loss = 0.08396402
# Iteration 580, loss = 0.08371818
# Iteration 581, loss = 0.08347341
# Iteration 582, loss = 0.08322970
# Iteration 583, loss = 0.08298705
# Iteration 584, loss = 0.08274544
# Iteration 585, loss = 0.08250488
# Iteration 586, loss = 0.08226536
# Iteration 587, loss = 0.08202686
# Iteration 588, loss = 0.08178940
# Iteration 589, loss = 0.08155295
# Iteration 590, loss = 0.08131751
# Iteration 591, loss = 0.08108309
# Iteration 592, loss = 0.08084966
# Iteration 593, loss = 0.08061723
# Iteration 594, loss = 0.08038579
# Iteration 595, loss = 0.08015534
# Iteration 596, loss = 0.07992586
# Iteration 597, loss = 0.07969736
# Iteration 598, loss = 0.07946982
# Iteration 599, loss = 0.07924325
# Iteration 600, loss = 0.07901763
# Iteration 601, loss = 0.07879297
# Iteration 602, loss = 0.07856925
# Iteration 603, loss = 0.07834647
# Iteration 604, loss = 0.07812463
# Iteration 605, loss = 0.07790371
# Iteration 606, loss = 0.07768372
# Iteration 607, loss = 0.07746465
# Iteration 608, loss = 0.07724650
# Iteration 609, loss = 0.07702925
# Iteration 610, loss = 0.07681290
# Iteration 611, loss = 0.07659746
# Iteration 612, loss = 0.07638291
# Iteration 613, loss = 0.07616925
# Iteration 614, loss = 0.07595647
# Iteration 615, loss = 0.07574457
# Iteration 616, loss = 0.07553354
# Iteration 617, loss = 0.07532338
# Iteration 618, loss = 0.07511409
# Iteration 619, loss = 0.07490566
# Iteration 620, loss = 0.07469808
# Iteration 621, loss = 0.07449135
# Iteration 622, loss = 0.07428546
# Iteration 623, loss = 0.07408042
# Iteration 624, loss = 0.07387621
# Iteration 625, loss = 0.07367284
# Iteration 626, loss = 0.07347029
# Iteration 627, loss = 0.07326856
# Iteration 628, loss = 0.07306765
# Iteration 629, loss = 0.07286755
# Iteration 630, loss = 0.07266826
# Iteration 631, loss = 0.07246978
# Iteration 632, loss = 0.07227210
# Iteration 633, loss = 0.07207521
# Iteration 634, loss = 0.07187911
# Iteration 635, loss = 0.07168380
# Iteration 636, loss = 0.07148927
# Iteration 637, loss = 0.07129552
# Iteration 638, loss = 0.07110255
# Iteration 639, loss = 0.07091034
# Iteration 640, loss = 0.07071890
# Iteration 641, loss = 0.07052823
# Iteration 642, loss = 0.07033831
# Iteration 643, loss = 0.07014914
# Iteration 644, loss = 0.06996072
# Iteration 645, loss = 0.06977305
# Iteration 646, loss = 0.06958612
# Iteration 647, loss = 0.06939993
# Iteration 648, loss = 0.06921447
# Iteration 649, loss = 0.06902974
# Iteration 650, loss = 0.06884574
# Iteration 651, loss = 0.06866246
# Iteration 652, loss = 0.06847990
# Iteration 653, loss = 0.06829805
# Iteration 654, loss = 0.06811692
# Iteration 655, loss = 0.06793649
# Iteration 656, loss = 0.06775676
# Iteration 657, loss = 0.06757773
# Iteration 658, loss = 0.06739940
# Iteration 659, loss = 0.06722176
# Iteration 660, loss = 0.06704481
# Iteration 661, loss = 0.06686854
# Iteration 662, loss = 0.06669296
# Iteration 663, loss = 0.06651805
# Iteration 664, loss = 0.06634382
# Iteration 665, loss = 0.06617026
# Iteration 666, loss = 0.06599736
# Iteration 667, loss = 0.06582513
# Iteration 668, loss = 0.06565356
# Iteration 669, loss = 0.06548265
# Iteration 670, loss = 0.06531239
# Iteration 671, loss = 0.06514278
# Iteration 672, loss = 0.06497382
# Iteration 673, loss = 0.06480550
# Iteration 674, loss = 0.06463782
# Iteration 675, loss = 0.06447078
# Iteration 676, loss = 0.06430437
# Iteration 677, loss = 0.06413859
# Iteration 678, loss = 0.06397344
# Iteration 679, loss = 0.06380891
# Iteration 680, loss = 0.06364501
# Iteration 681, loss = 0.06348172
# Iteration 682, loss = 0.06331904
# Iteration 683, loss = 0.06315698
# Iteration 684, loss = 0.06299553
# Iteration 685, loss = 0.06283468
# Iteration 686, loss = 0.06267443
# Iteration 687, loss = 0.06251478
# Iteration 688, loss = 0.06235573
# Iteration 689, loss = 0.06219727
# Iteration 690, loss = 0.06203940
# Iteration 691, loss = 0.06188212
# Iteration 692, loss = 0.06172543
# Iteration 693, loss = 0.06156931
# Iteration 694, loss = 0.06141377
# Iteration 695, loss = 0.06125881
# Iteration 696, loss = 0.06110442
# Iteration 697, loss = 0.06095060
# Iteration 698, loss = 0.06079735
# Iteration 699, loss = 0.06064466
# Iteration 700, loss = 0.06049253
# Iteration 701, loss = 0.06034097
# Iteration 702, loss = 0.06018995
# Iteration 703, loss = 0.06003949
# Iteration 704, loss = 0.05988958
# Iteration 705, loss = 0.05974022
# Iteration 706, loss = 0.05959140
# Iteration 707, loss = 0.05944313
# Iteration 708, loss = 0.05929539
# Iteration 709, loss = 0.05914820
# Iteration 710, loss = 0.05900153
# Iteration 711, loss = 0.05885540
# Iteration 712, loss = 0.05870980
# Iteration 713, loss = 0.05856472
# Iteration 714, loss = 0.05842017
# Iteration 715, loss = 0.05827613
# Iteration 716, loss = 0.05813262
# Iteration 717, loss = 0.05798962
# Iteration 718, loss = 0.05784714
# Iteration 719, loss = 0.05770517
# Iteration 720, loss = 0.05756371
# Iteration 721, loss = 0.05742275
# Iteration 722, loss = 0.05728230
# Iteration 723, loss = 0.05714235
# Iteration 724, loss = 0.05700290
# Iteration 725, loss = 0.05686394
# Iteration 726, loss = 0.05672548
# Iteration 727, loss = 0.05658751
# Iteration 728, loss = 0.05645003
# Iteration 729, loss = 0.05631304
# Iteration 730, loss = 0.05617653
# Iteration 731, loss = 0.05604051
# Iteration 732, loss = 0.05590496
# Iteration 733, loss = 0.05576990
# Iteration 734, loss = 0.05563531
# Iteration 735, loss = 0.05550119
# Iteration 736, loss = 0.05536754
# Iteration 737, loss = 0.05523437
# Iteration 738, loss = 0.05510166
# Iteration 739, loss = 0.05496941
# Iteration 740, loss = 0.05483763
# Iteration 741, loss = 0.05470631
# Iteration 742, loss = 0.05457544
# Iteration 743, loss = 0.05444503
# Iteration 744, loss = 0.05431508
# Iteration 745, loss = 0.05418557
# Iteration 746, loss = 0.05405652
# Iteration 747, loss = 0.05392791
# Iteration 748, loss = 0.05379975
# Iteration 749, loss = 0.05367204
# Iteration 750, loss = 0.05354476
# Iteration 751, loss = 0.05341792
# Iteration 752, loss = 0.05329152
# Iteration 753, loss = 0.05316556
# Iteration 754, loss = 0.05304002
# Iteration 755, loss = 0.05291492
# Iteration 756, loss = 0.05279025
# Iteration 757, loss = 0.05266601
# Iteration 758, loss = 0.05254219
# Iteration 759, loss = 0.05241879
# Iteration 760, loss = 0.05229581
# Iteration 761, loss = 0.05217326
# Iteration 762, loss = 0.05205112
# Iteration 763, loss = 0.05192939
# Iteration 764, loss = 0.05180808
# Iteration 765, loss = 0.05168719
# Iteration 766, loss = 0.05156670
# Iteration 767, loss = 0.05144662
# Iteration 768, loss = 0.05132694
# Iteration 769, loss = 0.05120767
# Iteration 770, loss = 0.05108880
# Iteration 771, loss = 0.05097033
# Iteration 772, loss = 0.05085227
# Iteration 773, loss = 0.05073459
# Iteration 774, loss = 0.05061732
# Iteration 775, loss = 0.05050043
# Iteration 776, loss = 0.05038394
# Iteration 777, loss = 0.05026784
# Iteration 778, loss = 0.05015212
# Iteration 779, loss = 0.05003679
# Iteration 780, loss = 0.04992185
# Iteration 781, loss = 0.04980729
# Iteration 782, loss = 0.04969311
# Iteration 783, loss = 0.04957931
# Iteration 784, loss = 0.04946588
# Iteration 785, loss = 0.04935284
# Iteration 786, loss = 0.04924016
# Iteration 787, loss = 0.04912786
# Iteration 788, loss = 0.04901593
# Iteration 789, loss = 0.04890437
# Iteration 790, loss = 0.04879318
# Iteration 791, loss = 0.04868236
# Iteration 792, loss = 0.04857189
# Iteration 793, loss = 0.04846179
# Iteration 794, loss = 0.04835206
# Iteration 795, loss = 0.04824268
# Iteration 796, loss = 0.04813366
# Iteration 797, loss = 0.04802499
# Iteration 798, loss = 0.04791669
# Iteration 799, loss = 0.04780873
# Iteration 800, loss = 0.04770113
# Iteration 801, loss = 0.04759387
# Iteration 802, loss = 0.04748697
# Iteration 803, loss = 0.04738041
# Iteration 804, loss = 0.04727420
# Iteration 805, loss = 0.04716833
# Iteration 806, loss = 0.04706280
# Iteration 807, loss = 0.04695762
# Iteration 808, loss = 0.04685277
# Iteration 809, loss = 0.04674827
# Iteration 810, loss = 0.04664410
# Iteration 811, loss = 0.04654026
# Iteration 812, loss = 0.04643676
# Iteration 813, loss = 0.04633359
# Iteration 814, loss = 0.04623076
# Iteration 815, loss = 0.04612825
# Iteration 816, loss = 0.04602607
# Iteration 817, loss = 0.04592421
# Iteration 818, loss = 0.04582269
# Iteration 819, loss = 0.04572148
# Iteration 820, loss = 0.04562060
# Iteration 821, loss = 0.04552004
# Iteration 822, loss = 0.04541980
# Iteration 823, loss = 0.04531987
# Iteration 824, loss = 0.04522027
# Iteration 825, loss = 0.04512098
# Iteration 826, loss = 0.04502200
# Iteration 827, loss = 0.04492334
# Iteration 828, loss = 0.04482499
# Iteration 829, loss = 0.04472695
# Iteration 830, loss = 0.04462921
# Iteration 831, loss = 0.04453179
# Iteration 832, loss = 0.04443467
# Iteration 833, loss = 0.04433786
# Iteration 834, loss = 0.04424135
# Iteration 835, loss = 0.04414514
# Iteration 836, loss = 0.04404923
# Iteration 837, loss = 0.04395363
# Iteration 838, loss = 0.04385832
# Iteration 839, loss = 0.04376331
# Iteration 840, loss = 0.04366860
# Iteration 841, loss = 0.04357418
# Iteration 842, loss = 0.04348005
# Iteration 843, loss = 0.04338622
# Iteration 844, loss = 0.04329268
# Iteration 845, loss = 0.04319943
# Iteration 846, loss = 0.04310646
# Iteration 847, loss = 0.04301379
# Iteration 848, loss = 0.04292140
# Iteration 849, loss = 0.04282930
# Iteration 850, loss = 0.04273748
# Iteration 851, loss = 0.04264594
# Iteration 852, loss = 0.04255468
# Iteration 853, loss = 0.04246371
# Iteration 854, loss = 0.04237302
# Iteration 855, loss = 0.04228260
# Iteration 856, loss = 0.04219246
# Iteration 857, loss = 0.04210259
# Iteration 858, loss = 0.04201300
# Iteration 859, loss = 0.04192369
# Iteration 860, loss = 0.04183465
# Iteration 861, loss = 0.04174587
# Iteration 862, loss = 0.04165737
# Iteration 863, loss = 0.04156914
# Iteration 864, loss = 0.04148118
# Iteration 865, loss = 0.04139348
# Iteration 866, loss = 0.04130605
# Iteration 867, loss = 0.04121888
# Iteration 868, loss = 0.04113198
# Iteration 869, loss = 0.04104534
# Iteration 870, loss = 0.04095896
# Iteration 871, loss = 0.04087284
# Iteration 872, loss = 0.04078698
# Iteration 873, loss = 0.04070138
# Iteration 874, loss = 0.04061604
# Iteration 875, loss = 0.04053095
# Iteration 876, loss = 0.04044612
# Iteration 877, loss = 0.04036155
# Iteration 878, loss = 0.04027722
# Iteration 879, loss = 0.04019315
# Iteration 880, loss = 0.04010933
# Iteration 881, loss = 0.04002576
# Iteration 882, loss = 0.03994244
# Iteration 883, loss = 0.03985937
# Iteration 884, loss = 0.03977654
# Iteration 885, loss = 0.03969396
# Iteration 886, loss = 0.03961163
# Iteration 887, loss = 0.03952954
# Iteration 888, loss = 0.03944769
# Iteration 889, loss = 0.03936609
# Iteration 890, loss = 0.03928473
# Iteration 891, loss = 0.03920360
# Iteration 892, loss = 0.03912272
# Iteration 893, loss = 0.03904208
# Iteration 894, loss = 0.03896167
# Iteration 895, loss = 0.03888150
# Iteration 896, loss = 0.03880156
# Iteration 897, loss = 0.03872186
# Iteration 898, loss = 0.03864240
# Iteration 899, loss = 0.03856317
# Iteration 900, loss = 0.03848416
# Iteration 901, loss = 0.03840539
# Iteration 902, loss = 0.03832685
# Iteration 903, loss = 0.03824854
# Iteration 904, loss = 0.03817046
# Iteration 905, loss = 0.03809261
# Iteration 906, loss = 0.03801498
# Iteration 907, loss = 0.03793758
# Iteration 908, loss = 0.03786040
# Iteration 909, loss = 0.03778344
# Iteration 910, loss = 0.03770671
# Iteration 911, loss = 0.03763020
# Iteration 912, loss = 0.03755392
# Iteration 913, loss = 0.03747785
# Iteration 914, loss = 0.03740200
# Iteration 915, loss = 0.03732637
# Iteration 916, loss = 0.03725096
# Iteration 917, loss = 0.03717577
# Iteration 918, loss = 0.03710079
# Iteration 919, loss = 0.03702603
# Iteration 920, loss = 0.03695148
# Iteration 921, loss = 0.03687715
# Iteration 922, loss = 0.03680303
# Iteration 923, loss = 0.03672912
# Iteration 924, loss = 0.03665543
# Iteration 925, loss = 0.03658194
# Iteration 926, loss = 0.03650866
# Iteration 927, loss = 0.03643559
# Iteration 928, loss = 0.03636273
# Iteration 929, loss = 0.03629008
# Iteration 930, loss = 0.03621763
# Iteration 931, loss = 0.03614539
# Iteration 932, loss = 0.03607336
# Iteration 933, loss = 0.03600153
# Iteration 934, loss = 0.03592990
# Iteration 935, loss = 0.03585847
# Iteration 936, loss = 0.03578725
# Iteration 937, loss = 0.03571623
# Iteration 938, loss = 0.03564541
# Iteration 939, loss = 0.03557478
# Iteration 940, loss = 0.03550436
# Iteration 941, loss = 0.03543413
# Iteration 942, loss = 0.03536410
# Iteration 943, loss = 0.03529427
# Iteration 944, loss = 0.03522464
# Iteration 945, loss = 0.03515519
# Iteration 946, loss = 0.03508595
# Iteration 947, loss = 0.03501689
# Iteration 948, loss = 0.03494803
# Iteration 949, loss = 0.03487937
# Iteration 950, loss = 0.03481089
# Iteration 951, loss = 0.03474260
# Iteration 952, loss = 0.03467451
# Iteration 953, loss = 0.03460660
# Iteration 954, loss = 0.03453888
# Iteration 955, loss = 0.03447135
# Iteration 956, loss = 0.03440401
# Iteration 957, loss = 0.03433685
# Iteration 958, loss = 0.03426988
# Iteration 959, loss = 0.03420310
# Iteration 960, loss = 0.03413650
# Iteration 961, loss = 0.03407008
# Iteration 962, loss = 0.03400385
# Iteration 963, loss = 0.03393780
# Iteration 964, loss = 0.03387193
# Iteration 965, loss = 0.03380624
# Iteration 966, loss = 0.03374073
# Iteration 967, loss = 0.03367540
# Iteration 968, loss = 0.03361025
# Iteration 969, loss = 0.03354528
# Iteration 970, loss = 0.03348049
# Iteration 971, loss = 0.03341587
# Iteration 972, loss = 0.03335143
# Iteration 973, loss = 0.03328717
# Iteration 974, loss = 0.03322308
# Iteration 975, loss = 0.03315917
# Iteration 976, loss = 0.03309543
# Iteration 977, loss = 0.03303186
# Iteration 978, loss = 0.03296847
# Iteration 979, loss = 0.03290524
# Iteration 980, loss = 0.03284219
# Iteration 981, loss = 0.03277931
# Iteration 982, loss = 0.03271660
# Iteration 983, loss = 0.03265406
# Iteration 984, loss = 0.03259169
# Iteration 985, loss = 0.03252949
# Iteration 986, loss = 0.03246746
# Iteration 987, loss = 0.03240559
# Iteration 988, loss = 0.03234389
# Iteration 989, loss = 0.03228235
# Iteration 990, loss = 0.03222098
# Iteration 991, loss = 0.03215978
# Iteration 992, loss = 0.03209874
# Iteration 993, loss = 0.03203786
# Iteration 994, loss = 0.03197714
# Iteration 995, loss = 0.03191659
# Iteration 996, loss = 0.03185620
# Iteration 997, loss = 0.03179597
# Iteration 998, loss = 0.03173590
# Iteration 999, loss = 0.03167600
# Iteration 1000, loss = 0.03161625
# Iteration 1001, loss = 0.03155666
# Iteration 1002, loss = 0.03149723
# Iteration 1003, loss = 0.03143795
# Iteration 1004, loss = 0.03137884
# Iteration 1005, loss = 0.03131988
# Iteration 1006, loss = 0.03126107
# Iteration 1007, loss = 0.03120243
# Iteration 1008, loss = 0.03114393
# Iteration 1009, loss = 0.03108559
# Iteration 1010, loss = 0.03102741
# Iteration 1011, loss = 0.03096938
# Iteration 1012, loss = 0.03091150
# Iteration 1013, loss = 0.03085378
# Iteration 1014, loss = 0.03079620
# Iteration 1015, loss = 0.03073878
# Iteration 1016, loss = 0.03068151
# Iteration 1017, loss = 0.03062439
# Iteration 1018, loss = 0.03056742
# Iteration 1019, loss = 0.03051059
# Iteration 1020, loss = 0.03045392
# Iteration 1021, loss = 0.03039739
# Iteration 1022, loss = 0.03034102
# Iteration 1023, loss = 0.03028479
# Iteration 1024, loss = 0.03022870
# Iteration 1025, loss = 0.03017276
# Iteration 1026, loss = 0.03011697
# Iteration 1027, loss = 0.03006132
# Iteration 1028, loss = 0.03000582
# Iteration 1029, loss = 0.02995046
# Iteration 1030, loss = 0.02989525
# Iteration 1031, loss = 0.02984017
# Iteration 1032, loss = 0.02978524
# Iteration 1033, loss = 0.02973046
# Iteration 1034, loss = 0.02967581
# Iteration 1035, loss = 0.02962131
# Iteration 1036, loss = 0.02956694
# Iteration 1037, loss = 0.02951272
# Iteration 1038, loss = 0.02945864
# Iteration 1039, loss = 0.02940469
# Iteration 1040, loss = 0.02935088
# Iteration 1041, loss = 0.02929722
# Iteration 1042, loss = 0.02924369
# Iteration 1043, loss = 0.02919029
# Iteration 1044, loss = 0.02913704
# Iteration 1045, loss = 0.02908392
# Iteration 1046, loss = 0.02903093
# Iteration 1047, loss = 0.02897809
# Iteration 1048, loss = 0.02892537
# Iteration 1049, loss = 0.02887279
# Iteration 1050, loss = 0.02882035
# Iteration 1051, loss = 0.02876804
# Iteration 1052, loss = 0.02871586
# Iteration 1053, loss = 0.02866382
# Iteration 1054, loss = 0.02861190
# Iteration 1055, loss = 0.02856012
# Iteration 1056, loss = 0.02850847
# Iteration 1057, loss = 0.02845695
# Iteration 1058, loss = 0.02840557
# Iteration 1059, loss = 0.02835431
# Iteration 1060, loss = 0.02830318
# Iteration 1061, loss = 0.02825218
# Iteration 1062, loss = 0.02820131
# Iteration 1063, loss = 0.02815057
# Iteration 1064, loss = 0.02809995
# Iteration 1065, loss = 0.02804947
# Iteration 1066, loss = 0.02799911
# Iteration 1067, loss = 0.02794887
# Iteration 1068, loss = 0.02789877
# Iteration 1069, loss = 0.02784879
# Iteration 1070, loss = 0.02779893
# Iteration 1071, loss = 0.02774920
# Iteration 1072, loss = 0.02769959
# Iteration 1073, loss = 0.02765011
# Iteration 1074, loss = 0.02760075
# Iteration 1075, loss = 0.02755152
# Iteration 1076, loss = 0.02750240
# Iteration 1077, loss = 0.02745341
# Iteration 1078, loss = 0.02740455
# Iteration 1079, loss = 0.02735580
# Iteration 1080, loss = 0.02730718
# Iteration 1081, loss = 0.02725867
# Iteration 1082, loss = 0.02721029
# Iteration 1083, loss = 0.02716202
# Iteration 1084, loss = 0.02711388
# Iteration 1085, loss = 0.02706586
# Iteration 1086, loss = 0.02701795
# Iteration 1087, loss = 0.02697016
# Iteration 1088, loss = 0.02692249
# Iteration 1089, loss = 0.02687494
# Iteration 1090, loss = 0.02682751
# Iteration 1091, loss = 0.02678019
# Iteration 1092, loss = 0.02673299
# Iteration 1093, loss = 0.02668591
# Iteration 1094, loss = 0.02663894
# Iteration 1095, loss = 0.02659209
# Iteration 1096, loss = 0.02654535
# Iteration 1097, loss = 0.02649873
# Iteration 1098, loss = 0.02645222
# Iteration 1099, loss = 0.02640582
# Iteration 1100, loss = 0.02635954
# Iteration 1101, loss = 0.02631337
# Iteration 1102, loss = 0.02626732
# Iteration 1103, loss = 0.02622137
# Iteration 1104, loss = 0.02617554
# Iteration 1105, loss = 0.02612982
# Iteration 1106, loss = 0.02608422
# Iteration 1107, loss = 0.02603872
# Iteration 1108, loss = 0.02599334
# Iteration 1109, loss = 0.02594806
# Iteration 1110, loss = 0.02590289
# Iteration 1111, loss = 0.02585784
# Iteration 1112, loss = 0.02581289
# Iteration 1113, loss = 0.02576805
# Iteration 1114, loss = 0.02572333
# Iteration 1115, loss = 0.02567870
# Iteration 1116, loss = 0.02563419
# Iteration 1117, loss = 0.02558979
# Iteration 1118, loss = 0.02554549
# Iteration 1119, loss = 0.02550130
# Iteration 1120, loss = 0.02545721
# Iteration 1121, loss = 0.02541323
# Iteration 1122, loss = 0.02536936
# Iteration 1123, loss = 0.02532559
# Iteration 1124, loss = 0.02528193
# Iteration 1125, loss = 0.02523837
# Iteration 1126, loss = 0.02519492
# Iteration 1127, loss = 0.02515157
# Iteration 1128, loss = 0.02510833
# Iteration 1129, loss = 0.02506518
# Iteration 1130, loss = 0.02502215
# Iteration 1131, loss = 0.02497921
# Iteration 1132, loss = 0.02493638
# Iteration 1133, loss = 0.02489365
# Iteration 1134, loss = 0.02485102
# Iteration 1135, loss = 0.02480849
# Iteration 1136, loss = 0.02476606
# Iteration 1137, loss = 0.02472374
# Iteration 1138, loss = 0.02468151
# Iteration 1139, loss = 0.02463939
# Iteration 1140, loss = 0.02459737
# Iteration 1141, loss = 0.02455544
# Iteration 1142, loss = 0.02451362
# Iteration 1143, loss = 0.02447189
# Iteration 1144, loss = 0.02443026
# Iteration 1145, loss = 0.02438873
# Iteration 1146, loss = 0.02434730
# Iteration 1147, loss = 0.02430597
# Iteration 1148, loss = 0.02426473
# Iteration 1149, loss = 0.02422359
# Iteration 1150, loss = 0.02418255
# Iteration 1151, loss = 0.02414161
# Iteration 1152, loss = 0.02410076
# Iteration 1153, loss = 0.02406001
# Iteration 1154, loss = 0.02401935
# Iteration 1155, loss = 0.02397879
# Iteration 1156, loss = 0.02393832
# Iteration 1157, loss = 0.02389795
# Iteration 1158, loss = 0.02385767
# Iteration 1159, loss = 0.02381749
# Iteration 1160, loss = 0.02377740
# Iteration 1161, loss = 0.02373741
# Iteration 1162, loss = 0.02369750
# Iteration 1163, loss = 0.02365770
# Iteration 1164, loss = 0.02361798
# Iteration 1165, loss = 0.02357836
# Iteration 1166, loss = 0.02353882
# Iteration 1167, loss = 0.02349939
# Iteration 1168, loss = 0.02346004
# Iteration 1169, loss = 0.02342078
# Iteration 1170, loss = 0.02338162
# Iteration 1171, loss = 0.02334254
# Iteration 1172, loss = 0.02330356
# Iteration 1173, loss = 0.02326467
# Iteration 1174, loss = 0.02322586
# Iteration 1175, loss = 0.02318715
# Iteration 1176, loss = 0.02314852
# Iteration 1177, loss = 0.02310999
# Iteration 1178, loss = 0.02307154
# Iteration 1179, loss = 0.02303318
# Iteration 1180, loss = 0.02299492
# Iteration 1181, loss = 0.02295673
# Iteration 1182, loss = 0.02291864
# Iteration 1183, loss = 0.02288064
# Iteration 1184, loss = 0.02284272
# Iteration 1185, loss = 0.02280489
# Iteration 1186, loss = 0.02276714
# Iteration 1187, loss = 0.02272948
# Iteration 1188, loss = 0.02269191
# Iteration 1189, loss = 0.02265443
# Iteration 1190, loss = 0.02261703
# Iteration 1191, loss = 0.02257971
# Iteration 1192, loss = 0.02254248
# Iteration 1193, loss = 0.02250534
# Iteration 1194, loss = 0.02246828
# Iteration 1195, loss = 0.02243130
# Iteration 1196, loss = 0.02239441
# Iteration 1197, loss = 0.02235760
# Iteration 1198, loss = 0.02232088
# Iteration 1199, loss = 0.02228424
# Iteration 1200, loss = 0.02224768
# Iteration 1201, loss = 0.02221121
# Iteration 1202, loss = 0.02217482
# Iteration 1203, loss = 0.02213851
# Iteration 1204, loss = 0.02210229
# Iteration 1205, loss = 0.02206614
# Iteration 1206, loss = 0.02203008
# Iteration 1207, loss = 0.02199410
# Iteration 1208, loss = 0.02195820
# Iteration 1209, loss = 0.02192238
# Iteration 1210, loss = 0.02188664
# Iteration 1211, loss = 0.02185098
# Iteration 1212, loss = 0.02181541
# Iteration 1213, loss = 0.02177991
# Iteration 1214, loss = 0.02174449
# Iteration 1215, loss = 0.02170915
# Iteration 1216, loss = 0.02167390
# Iteration 1217, loss = 0.02163872
# Iteration 1218, loss = 0.02160362
# Iteration 1219, loss = 0.02156859
# Iteration 1220, loss = 0.02153365
# Iteration 1221, loss = 0.02149879
# Iteration 1222, loss = 0.02146400
# Iteration 1223, loss = 0.02142929
# Iteration 1224, loss = 0.02139466
# Iteration 1225, loss = 0.02136010
# Iteration 1226, loss = 0.02132562
# Iteration 1227, loss = 0.02129122
# Iteration 1228, loss = 0.02125690
# Iteration 1229, loss = 0.02122265
# Iteration 1230, loss = 0.02118848
# Iteration 1231, loss = 0.02115438
# Iteration 1232, loss = 0.02112036
# Iteration 1233, loss = 0.02108642
# Iteration 1234, loss = 0.02105255
# Iteration 1235, loss = 0.02101876
# Iteration 1236, loss = 0.02098504
# Iteration 1237, loss = 0.02095139
# Iteration 1238, loss = 0.02091782
# Iteration 1239, loss = 0.02088432
# Iteration 1240, loss = 0.02085090
# Iteration 1241, loss = 0.02081755
# Iteration 1242, loss = 0.02078428
# Iteration 1243, loss = 0.02075108
# Iteration 1244, loss = 0.02071795
# Iteration 1245, loss = 0.02068489
# Iteration 1246, loss = 0.02065191
# Iteration 1247, loss = 0.02061900
# Iteration 1248, loss = 0.02058616
# Iteration 1249, loss = 0.02055340
# Iteration 1250, loss = 0.02052070
# Iteration 1251, loss = 0.02048808
# Iteration 1252, loss = 0.02045553
# Iteration 1253, loss = 0.02042305
# Iteration 1254, loss = 0.02039064
# Iteration 1255, loss = 0.02035830
# Iteration 1256, loss = 0.02032603
# Iteration 1257, loss = 0.02029384
# Iteration 1258, loss = 0.02026171
# Iteration 1259, loss = 0.02022965
# Iteration 1260, loss = 0.02019767
# Iteration 1261, loss = 0.02016575
# Iteration 1262, loss = 0.02013390
# Iteration 1263, loss = 0.02010213
# Iteration 1264, loss = 0.02007042
# Iteration 1265, loss = 0.02003878
# Iteration 1266, loss = 0.02000720
# Iteration 1267, loss = 0.01997570
# Iteration 1268, loss = 0.01994427
# Iteration 1269, loss = 0.01991290
# Iteration 1270, loss = 0.01988160
# Iteration 1271, loss = 0.01985037
# Iteration 1272, loss = 0.01981920
# Iteration 1273, loss = 0.01978811
# Iteration 1274, loss = 0.01975708
# Iteration 1275, loss = 0.01972611
# Iteration 1276, loss = 0.01969522
# Iteration 1277, loss = 0.01966439
# Iteration 1278, loss = 0.01963363
# Iteration 1279, loss = 0.01960293
# Iteration 1280, loss = 0.01957230
# Iteration 1281, loss = 0.01954173
# Iteration 1282, loss = 0.01951124
# Iteration 1283, loss = 0.01948080
# Iteration 1284, loss = 0.01945043
# Iteration 1285, loss = 0.01942013
# Iteration 1286, loss = 0.01938989
# Iteration 1287, loss = 0.01935972
# Iteration 1288, loss = 0.01932961
# Iteration 1289, loss = 0.01929956
# Iteration 1290, loss = 0.01926958
# Iteration 1291, loss = 0.01923966
# Iteration 1292, loss = 0.01920981
# Iteration 1293, loss = 0.01918002
# Iteration 1294, loss = 0.01915030
# Iteration 1295, loss = 0.01912063
# Iteration 1296, loss = 0.01909103
# Iteration 1297, loss = 0.01906150
# Iteration 1298, loss = 0.01903202
# Iteration 1299, loss = 0.01900261
# Iteration 1300, loss = 0.01897326
# Iteration 1301, loss = 0.01894397
# Iteration 1302, loss = 0.01891475
# Iteration 1303, loss = 0.01888559
# Iteration 1304, loss = 0.01885649
# Iteration 1305, loss = 0.01882745
# Iteration 1306, loss = 0.01879847
# Iteration 1307, loss = 0.01876955
# Iteration 1308, loss = 0.01874070
# Iteration 1309, loss = 0.01871190
# Iteration 1310, loss = 0.01868317
# Iteration 1311, loss = 0.01865449
# Iteration 1312, loss = 0.01862588
# Iteration 1313, loss = 0.01859733
# Iteration 1314, loss = 0.01856883
# Iteration 1315, loss = 0.01854040
# Iteration 1316, loss = 0.01851203
# Iteration 1317, loss = 0.01848371
# Iteration 1318, loss = 0.01845546
# Iteration 1319, loss = 0.01842726
# Iteration 1320, loss = 0.01839912
# Iteration 1321, loss = 0.01837105
# Iteration 1322, loss = 0.01834303
# Iteration 1323, loss = 0.01831507
# Iteration 1324, loss = 0.01828717
# Iteration 1325, loss = 0.01825932
# Iteration 1326, loss = 0.01823154
# Iteration 1327, loss = 0.01820381
# Iteration 1328, loss = 0.01817614
# Iteration 1329, loss = 0.01814853
# Iteration 1330, loss = 0.01812097
# Iteration 1331, loss = 0.01809348
# Iteration 1332, loss = 0.01806604
# Iteration 1333, loss = 0.01803865
# Iteration 1334, loss = 0.01801133
# Iteration 1335, loss = 0.01798406
# Iteration 1336, loss = 0.01795684
# Iteration 1337, loss = 0.01792969
# Iteration 1338, loss = 0.01790259
# Iteration 1339, loss = 0.01787554
# Iteration 1340, loss = 0.01784856
# Iteration 1341, loss = 0.01782162
# Iteration 1342, loss = 0.01779475
# Iteration 1343, loss = 0.01776792
# Iteration 1344, loss = 0.01774116
# Iteration 1345, loss = 0.01771445
# Iteration 1346, loss = 0.01768779
# Iteration 1347, loss = 0.01766119
# Iteration 1348, loss = 0.01763464
# Iteration 1349, loss = 0.01760815
# Iteration 1350, loss = 0.01758172
# Iteration 1351, loss = 0.01755533
# Iteration 1352, loss = 0.01752900
# Iteration 1353, loss = 0.01750273
# Iteration 1354, loss = 0.01747651
# Iteration 1355, loss = 0.01745034
# Iteration 1356, loss = 0.01742423
# Iteration 1357, loss = 0.01739817
# Iteration 1358, loss = 0.01737216
# Iteration 1359, loss = 0.01734621
# Iteration 1360, loss = 0.01732031
# Iteration 1361, loss = 0.01729446
# Iteration 1362, loss = 0.01726867
# Iteration 1363, loss = 0.01724292
# Iteration 1364, loss = 0.01721723
# Iteration 1365, loss = 0.01719160
# Iteration 1366, loss = 0.01716601
# Iteration 1367, loss = 0.01714048
# Iteration 1368, loss = 0.01711500
# Iteration 1369, loss = 0.01708957
# Iteration 1370, loss = 0.01706419
# Iteration 1371, loss = 0.01703886
# Iteration 1372, loss = 0.01701359
# Iteration 1373, loss = 0.01698836
# Iteration 1374, loss = 0.01696319
# Iteration 1375, loss = 0.01693807
# Iteration 1376, loss = 0.01691300
# Iteration 1377, loss = 0.01688798
# Iteration 1378, loss = 0.01686301
# Iteration 1379, loss = 0.01683809
# Iteration 1380, loss = 0.01681322
# Iteration 1381, loss = 0.01678840
# Iteration 1382, loss = 0.01676363
# Iteration 1383, loss = 0.01673891
# Iteration 1384, loss = 0.01671424
# Iteration 1385, loss = 0.01668962
# Iteration 1386, loss = 0.01666505
# Iteration 1387, loss = 0.01664053
# Iteration 1388, loss = 0.01661606
# Iteration 1389, loss = 0.01659164
# Iteration 1390, loss = 0.01656726
# Iteration 1391, loss = 0.01654294
# Iteration 1392, loss = 0.01651866
# Iteration 1393, loss = 0.01649444
# Iteration 1394, loss = 0.01647026
# Iteration 1395, loss = 0.01644613
# Iteration 1396, loss = 0.01642204
# Iteration 1397, loss = 0.01639801
# Iteration 1398, loss = 0.01637402
# Iteration 1399, loss = 0.01635009
# Iteration 1400, loss = 0.01632620
# Iteration 1401, loss = 0.01630235
# Iteration 1402, loss = 0.01627856
# Iteration 1403, loss = 0.01625481
# Iteration 1404, loss = 0.01623111
# Iteration 1405, loss = 0.01620745
# Iteration 1406, loss = 0.01618385
# Iteration 1407, loss = 0.01616029
# Iteration 1408, loss = 0.01613677
# Iteration 1409, loss = 0.01611331
# Iteration 1410, loss = 0.01608989
# Iteration 1411, loss = 0.01606651
# Iteration 1412, loss = 0.01604319
# Iteration 1413, loss = 0.01601991
# Iteration 1414, loss = 0.01599667
# Iteration 1415, loss = 0.01597348
# Iteration 1416, loss = 0.01595034
# Iteration 1417, loss = 0.01592724
# Iteration 1418, loss = 0.01590419
# Iteration 1419, loss = 0.01588118
# Iteration 1420, loss = 0.01585822
# Iteration 1421, loss = 0.01583530
# Iteration 1422, loss = 0.01581243
# Iteration 1423, loss = 0.01578961
# Iteration 1424, loss = 0.01576683
# Iteration 1425, loss = 0.01574409
# Iteration 1426, loss = 0.01572140
# Iteration 1427, loss = 0.01569875
# Iteration 1428, loss = 0.01567615
# Iteration 1429, loss = 0.01565359
# Iteration 1430, loss = 0.01563107
# Iteration 1431, loss = 0.01560860
# Iteration 1432, loss = 0.01558618
# Iteration 1433, loss = 0.01556380
# Iteration 1434, loss = 0.01554146
# Iteration 1435, loss = 0.01551916
# Iteration 1436, loss = 0.01549691
# Iteration 1437, loss = 0.01547470
# Iteration 1438, loss = 0.01545254
# Iteration 1439, loss = 0.01543042
# Iteration 1440, loss = 0.01540834
# Iteration 1441, loss = 0.01538630
# Iteration 1442, loss = 0.01536431
# Iteration 1443, loss = 0.01534236
# Iteration 1444, loss = 0.01532045
# ...
# Iteration 3466, loss = 0.00197983
# Iteration 3467, loss = 0.00197832
# Iteration 3468, loss = 0.00197681
# Iteration 3469, loss = 0.00197531
# Iteration 3470, loss = 0.00197380
# Iteration 3471, loss = 0.00197230
# Iteration 3472, loss = 0.00197080
# Iteration 3473, loss = 0.00196930
# Iteration 3474, loss = 0.00196781
# Iteration 3475, loss = 0.00196631
# Iteration 3476, loss = 0.00196481
# Iteration 3477, loss = 0.00196332
# Iteration 3478, loss = 0.00196183
# Iteration 3479, loss = 0.00196034
# Iteration 3480, loss = 0.00195885
# Iteration 3481, loss = 0.00195736
# Iteration 3482, loss = 0.00195588
# Iteration 3483, loss = 0.00195439
# Iteration 3484, loss = 0.00195291
# Iteration 3485, loss = 0.00195143
# Iteration 3486, loss = 0.00194995
# Iteration 3487, loss = 0.00194847
# Iteration 3488, loss = 0.00194699
# Iteration 3489, loss = 0.00194552
# Iteration 3490, loss = 0.00194404
# Iteration 3491, loss = 0.00194257
# Iteration 3492, loss = 0.00194110
# Iteration 3493, loss = 0.00193963
# Iteration 3494, loss = 0.00193816
# Iteration 3495, loss = 0.00193669
# Iteration 3496, loss = 0.00193523
# Iteration 3497, loss = 0.00193376
# Iteration 3498, loss = 0.00193230
# Iteration 3499, loss = 0.00193084
# Iteration 3500, loss = 0.00192938
# Iteration 3501, loss = 0.00192792
# Iteration 3502, loss = 0.00192646
# Iteration 3503, loss = 0.00192500
# Iteration 3504, loss = 0.00192355
# Iteration 3505, loss = 0.00192210
# Iteration 3506, loss = 0.00192065
# Iteration 3507, loss = 0.00191919
# Iteration 3508, loss = 0.00191775
# Iteration 3509, loss = 0.00191630
# Iteration 3510, loss = 0.00191485
# Iteration 3511, loss = 0.00191341
# Iteration 3512, loss = 0.00191196
# Iteration 3513, loss = 0.00191052
# Iteration 3514, loss = 0.00190908
# Iteration 3515, loss = 0.00190764
# Iteration 3516, loss = 0.00190620
# Iteration 3517, loss = 0.00190477
# Iteration 3518, loss = 0.00190333
# Iteration 3519, loss = 0.00190190
# Iteration 3520, loss = 0.00190047
# Iteration 3521, loss = 0.00189904
# Iteration 3522, loss = 0.00189761
# Iteration 3523, loss = 0.00189618
# Iteration 3524, loss = 0.00189475
# Iteration 3525, loss = 0.00189333
# Iteration 3526, loss = 0.00189190
# Iteration 3527, loss = 0.00189048
# Iteration 3528, loss = 0.00188906
# Iteration 3529, loss = 0.00188764
# Iteration 3530, loss = 0.00188622
# Iteration 3531, loss = 0.00188480
# Iteration 3532, loss = 0.00188339
# Iteration 3533, loss = 0.00188197
# Iteration 3534, loss = 0.00188056
# Iteration 3535, loss = 0.00187915
# Iteration 3536, loss = 0.00187774
# Iteration 3537, loss = 0.00187633
# Iteration 3538, loss = 0.00187492
# Iteration 3539, loss = 0.00187351
# Iteration 3540, loss = 0.00187211
# Iteration 3541, loss = 0.00187070
# Iteration 3542, loss = 0.00186930
# Iteration 3543, loss = 0.00186790
# Iteration 3544, loss = 0.00186650
# Iteration 3545, loss = 0.00186510
# Iteration 3546, loss = 0.00186370
# Iteration 3547, loss = 0.00186231
# Iteration 3548, loss = 0.00186091
# Iteration 3549, loss = 0.00185952
# Iteration 3550, loss = 0.00185813
# Iteration 3551, loss = 0.00185674
# Iteration 3552, loss = 0.00185535
# Iteration 3553, loss = 0.00185396
# Iteration 3554, loss = 0.00185258
# Iteration 3555, loss = 0.00185119
# Iteration 3556, loss = 0.00184981
# Iteration 3557, loss = 0.00184842
# Iteration 3558, loss = 0.00184704
# Iteration 3559, loss = 0.00184566
# Iteration 3560, loss = 0.00184428
# Iteration 3561, loss = 0.00184291
# Iteration 3562, loss = 0.00184153
# Iteration 3563, loss = 0.00184016
# Iteration 3564, loss = 0.00183878
# Iteration 3565, loss = 0.00183741
# Iteration 3566, loss = 0.00183604
# Iteration 3567, loss = 0.00183467
# Iteration 3568, loss = 0.00183330
# Iteration 3569, loss = 0.00183194
# Iteration 3570, loss = 0.00183057
# Iteration 3571, loss = 0.00182921
# Iteration 3572, loss = 0.00182784
# Iteration 3573, loss = 0.00182648
# Iteration 3574, loss = 0.00182512
# Iteration 3575, loss = 0.00182376
# Iteration 3576, loss = 0.00182241
# Iteration 3577, loss = 0.00182105
# Iteration 3578, loss = 0.00181969
# Iteration 3579, loss = 0.00181834
# Iteration 3580, loss = 0.00181699
# Iteration 3581, loss = 0.00181564
# Iteration 3582, loss = 0.00181429
# Iteration 3583, loss = 0.00181294
# Iteration 3584, loss = 0.00181159
# Iteration 3585, loss = 0.00181024
# Iteration 3586, loss = 0.00180890
# Iteration 3587, loss = 0.00180756
# Iteration 3588, loss = 0.00180621
# Iteration 3589, loss = 0.00180487
# Iteration 3590, loss = 0.00180353
# Iteration 3591, loss = 0.00180219
# Iteration 3592, loss = 0.00180086
# Iteration 3593, loss = 0.00179952
# Iteration 3594, loss = 0.00179819
# Iteration 3595, loss = 0.00179685
# Iteration 3596, loss = 0.00179552
# Iteration 3597, loss = 0.00179419
# Iteration 3598, loss = 0.00179286
# Iteration 3599, loss = 0.00179153
# Iteration 3600, loss = 0.00179020
# Iteration 3601, loss = 0.00178888
# Iteration 3602, loss = 0.00178755
# Iteration 3603, loss = 0.00178623
# Iteration 3604, loss = 0.00178491
# Iteration 3605, loss = 0.00178359
# Iteration 3606, loss = 0.00178227
# Iteration 3607, loss = 0.00178095
# Iteration 3608, loss = 0.00177963
# Iteration 3609, loss = 0.00177832
# Iteration 3610, loss = 0.00177700
# Iteration 3611, loss = 0.00177569
# Iteration 3612, loss = 0.00177438
# Iteration 3613, loss = 0.00177306
# Iteration 3614, loss = 0.00177175
# Iteration 3615, loss = 0.00177045
# Iteration 3616, loss = 0.00176914
# Iteration 3617, loss = 0.00176783
# Iteration 3618, loss = 0.00176653
# Iteration 3619, loss = 0.00176522
# Iteration 3620, loss = 0.00176392
# Iteration 3621, loss = 0.00176262
# Iteration 3622, loss = 0.00176132
# Iteration 3623, loss = 0.00176002
# Iteration 3624, loss = 0.00175873
# Iteration 3625, loss = 0.00175743
# Iteration 3626, loss = 0.00175613
# Iteration 3627, loss = 0.00175484
# Iteration 3628, loss = 0.00175355
# Iteration 3629, loss = 0.00175226
# Iteration 3630, loss = 0.00175097
# Iteration 3631, loss = 0.00174968
# Iteration 3632, loss = 0.00174839
# Iteration 3633, loss = 0.00174710
# Iteration 3634, loss = 0.00174582
# Iteration 3635, loss = 0.00174453
# Iteration 3636, loss = 0.00174325
# Iteration 3637, loss = 0.00174197
# Iteration 3638, loss = 0.00174069
# Iteration 3639, loss = 0.00173941
# Iteration 3640, loss = 0.00173813
# Iteration 3641, loss = 0.00173685
# Iteration 3642, loss = 0.00173558
# Iteration 3643, loss = 0.00173430
# Iteration 3644, loss = 0.00173303
# Iteration 3645, loss = 0.00173176
# Iteration 3646, loss = 0.00173049
# Iteration 3647, loss = 0.00172922
# Iteration 3648, loss = 0.00172795
# Iteration 3649, loss = 0.00172668
# Iteration 3650, loss = 0.00172541
# Iteration 3651, loss = 0.00172415
# Iteration 3652, loss = 0.00172289
# Iteration 3653, loss = 0.00172162
# Iteration 3654, loss = 0.00172036
# Iteration 3655, loss = 0.00171910
# Iteration 3656, loss = 0.00171784
# Iteration 3657, loss = 0.00171658
# Iteration 3658, loss = 0.00171533
# Iteration 3659, loss = 0.00171407
# Iteration 3660, loss = 0.00171282
# Iteration 3661, loss = 0.00171156
# Iteration 3662, loss = 0.00171031
# Iteration 3663, loss = 0.00170906
# Iteration 3664, loss = 0.00170781
# Iteration 3665, loss = 0.00170656
# Iteration 3666, loss = 0.00170532
# Iteration 3667, loss = 0.00170407
# Iteration 3668, loss = 0.00170282
# Iteration 3669, loss = 0.00170158
# Iteration 3670, loss = 0.00170034
# Iteration 3671, loss = 0.00169910
# Iteration 3672, loss = 0.00169786
# Iteration 3673, loss = 0.00169662
# Iteration 3674, loss = 0.00169538
# Iteration 3675, loss = 0.00169414
# Iteration 3676, loss = 0.00169290
# Iteration 3677, loss = 0.00169167
# Iteration 3678, loss = 0.00169044
# Iteration 3679, loss = 0.00168920
# Iteration 3680, loss = 0.00168797
# Iteration 3681, loss = 0.00168674
# Iteration 3682, loss = 0.00168551
# Iteration 3683, loss = 0.00168429
# Iteration 3684, loss = 0.00168306
# Iteration 3685, loss = 0.00168183
# Iteration 3686, loss = 0.00168061
# Iteration 3687, loss = 0.00167939
# Iteration 3688, loss = 0.00167816
# Iteration 3689, loss = 0.00167694
# Iteration 3690, loss = 0.00167572
# Iteration 3691, loss = 0.00167450
# Iteration 3692, loss = 0.00167329
# Iteration 3693, loss = 0.00167207
# Iteration 3694, loss = 0.00167085
# Iteration 3695, loss = 0.00166964
# Iteration 3696, loss = 0.00166843
# Iteration 3697, loss = 0.00166721
# Iteration 3698, loss = 0.00166600
# Iteration 3699, loss = 0.00166479
# Iteration 3700, loss = 0.00166359
# Iteration 3701, loss = 0.00166238
# Iteration 3702, loss = 0.00166117
# Iteration 3703, loss = 0.00165997
# Iteration 3704, loss = 0.00165876
# Iteration 3705, loss = 0.00165756
# Iteration 3706, loss = 0.00165636
# Iteration 3707, loss = 0.00165516
# Iteration 3708, loss = 0.00165396
# Iteration 3709, loss = 0.00165276
# Iteration 3710, loss = 0.00165156
# Iteration 3711, loss = 0.00165036
# Iteration 3712, loss = 0.00164917
# Iteration 3713, loss = 0.00164797
# Iteration 3714, loss = 0.00164678
# Iteration 3715, loss = 0.00164559
# Iteration 3716, loss = 0.00164440
# Iteration 3717, loss = 0.00164321
# Iteration 3718, loss = 0.00164202
# Iteration 3719, loss = 0.00164083
# Iteration 3720, loss = 0.00163965
# Iteration 3721, loss = 0.00163846
# Iteration 3722, loss = 0.00163728
# Iteration 3723, loss = 0.00163609
# Iteration 3724, loss = 0.00163491
# Iteration 3725, loss = 0.00163373
# Iteration 3726, loss = 0.00163255
# Iteration 3727, loss = 0.00163137
# Iteration 3728, loss = 0.00163019
# Iteration 3729, loss = 0.00162902
# Iteration 3730, loss = 0.00162784
# Iteration 3731, loss = 0.00162667
# Iteration 3732, loss = 0.00162549
# Iteration 3733, loss = 0.00162432
# Iteration 3734, loss = 0.00162315
# Iteration 3735, loss = 0.00162198
# Iteration 3736, loss = 0.00162081
# Iteration 3737, loss = 0.00161964
# Iteration 3738, loss = 0.00161847
# Iteration 3739, loss = 0.00161731
# Iteration 3740, loss = 0.00161614
# Iteration 3741, loss = 0.00161498
# Iteration 3742, loss = 0.00161382
# Iteration 3743, loss = 0.00161265
# Iteration 3744, loss = 0.00161149
# Iteration 3745, loss = 0.00161033
# Iteration 3746, loss = 0.00160918
# Iteration 3747, loss = 0.00160802
# Iteration 3748, loss = 0.00160686
# Iteration 3749, loss = 0.00160571
# Iteration 3750, loss = 0.00160455
# Iteration 3751, loss = 0.00160340
# Iteration 3752, loss = 0.00160225
# Iteration 3753, loss = 0.00160110
# Iteration 3754, loss = 0.00159995
# Iteration 3755, loss = 0.00159880
# Iteration 3756, loss = 0.00159765
# Iteration 3757, loss = 0.00159650
# Iteration 3758, loss = 0.00159536
# Iteration 3759, loss = 0.00159421
# Iteration 3760, loss = 0.00159307
# Iteration 3761, loss = 0.00159193
# Iteration 3762, loss = 0.00159078
# Iteration 3763, loss = 0.00158964
# Iteration 3764, loss = 0.00158850
# Iteration 3765, loss = 0.00158736
# Iteration 3766, loss = 0.00158623
# Iteration 3767, loss = 0.00158509
# Iteration 3768, loss = 0.00158396
# Iteration 3769, loss = 0.00158282
# Iteration 3770, loss = 0.00158169
# Iteration 3771, loss = 0.00158056
# Iteration 3772, loss = 0.00157942
# Iteration 3773, loss = 0.00157829
# Iteration 3774, loss = 0.00157716
# Iteration 3775, loss = 0.00157604
# Iteration 3776, loss = 0.00157491
# Iteration 3777, loss = 0.00157378
# Iteration 3778, loss = 0.00157266
# Iteration 3779, loss = 0.00157153
# Iteration 3780, loss = 0.00157041
# Iteration 3781, loss = 0.00156929
# Iteration 3782, loss = 0.00156817
# Iteration 3783, loss = 0.00156705
# Iteration 3784, loss = 0.00156593
# Iteration 3785, loss = 0.00156481
# Iteration 3786, loss = 0.00156369
# Iteration 3787, loss = 0.00156258
# Iteration 3788, loss = 0.00156146
# Iteration 3789, loss = 0.00156035
# Iteration 3790, loss = 0.00155924
# Iteration 3791, loss = 0.00155812
# Iteration 3792, loss = 0.00155701
# Iteration 3793, loss = 0.00155590
# Iteration 3794, loss = 0.00155480
# Iteration 3795, loss = 0.00155369
# Iteration 3796, loss = 0.00155258
# Iteration 3797, loss = 0.00155147
# Iteration 3798, loss = 0.00155037
# Iteration 3799, loss = 0.00154927
# Iteration 3800, loss = 0.00154816
# Iteration 3801, loss = 0.00154706
# Iteration 3802, loss = 0.00154596
# Iteration 3803, loss = 0.00154486
# Iteration 3804, loss = 0.00154376
# Iteration 3805, loss = 0.00154266
# Iteration 3806, loss = 0.00154157
# Iteration 3807, loss = 0.00154047
# Iteration 3808, loss = 0.00153938
# Iteration 3809, loss = 0.00153828
# Iteration 3810, loss = 0.00153719
# Iteration 3811, loss = 0.00153610
# Iteration 3812, loss = 0.00153501
# Iteration 3813, loss = 0.00153392
# Iteration 3814, loss = 0.00153283
# Iteration 3815, loss = 0.00153174
# Iteration 3816, loss = 0.00153065
# Iteration 3817, loss = 0.00152957
# Iteration 3818, loss = 0.00152848
# Iteration 3819, loss = 0.00152740
# Iteration 3820, loss = 0.00152632
# Iteration 3821, loss = 0.00152523
# Iteration 3822, loss = 0.00152415
# Iteration 3823, loss = 0.00152307
# Iteration 3824, loss = 0.00152199
# Iteration 3825, loss = 0.00152091
# Iteration 3826, loss = 0.00151984
# Iteration 3827, loss = 0.00151876
# Iteration 3828, loss = 0.00151769
# Iteration 3829, loss = 0.00151661
# Iteration 3830, loss = 0.00151554
# Iteration 3831, loss = 0.00151447
# Iteration 3832, loss = 0.00151339
# Iteration 3833, loss = 0.00151232
# Iteration 3834, loss = 0.00151125
# Iteration 3835, loss = 0.00151019
# Iteration 3836, loss = 0.00150912
# Iteration 3837, loss = 0.00150805
# Iteration 3838, loss = 0.00150699
# Iteration 3839, loss = 0.00150592
# Iteration 3840, loss = 0.00150486
# Iteration 3841, loss = 0.00150380
# Iteration 3842, loss = 0.00150273
# Iteration 3843, loss = 0.00150167
# Iteration 3844, loss = 0.00150061
# Iteration 3845, loss = 0.00149955
# Iteration 3846, loss = 0.00149850
# Iteration 3847, loss = 0.00149744
# Iteration 3848, loss = 0.00149638
# Iteration 3849, loss = 0.00149533
# Iteration 3850, loss = 0.00149427
# Iteration 3851, loss = 0.00149322
# Iteration 3852, loss = 0.00149217
# Iteration 3853, loss = 0.00149112
# Iteration 3854, loss = 0.00149007
# Iteration 3855, loss = 0.00148902
# Iteration 3856, loss = 0.00148797
# Iteration 3857, loss = 0.00148692
# Iteration 3858, loss = 0.00148587
# Iteration 3859, loss = 0.00148483
# Iteration 3860, loss = 0.00148378
# Iteration 3861, loss = 0.00148274
# Iteration 3862, loss = 0.00148170
# Iteration 3863, loss = 0.00148066
# Iteration 3864, loss = 0.00147961
# Iteration 3865, loss = 0.00147857
# Iteration 3866, loss = 0.00147754
# Iteration 3867, loss = 0.00147650
# Iteration 3868, loss = 0.00147546
# Iteration 3869, loss = 0.00147442
# Iteration 3870, loss = 0.00147339
# Iteration 3871, loss = 0.00147235
# Iteration 3872, loss = 0.00147132
# Iteration 3873, loss = 0.00147029
# Iteration 3874, loss = 0.00146926
# Iteration 3875, loss = 0.00146823
# Iteration 3876, loss = 0.00146720
# Iteration 3877, loss = 0.00146617
# Iteration 3878, loss = 0.00146514
# Iteration 3879, loss = 0.00146411
# Iteration 3880, loss = 0.00146308
# Iteration 3881, loss = 0.00146206
# Iteration 3882, loss = 0.00146104
# Iteration 3883, loss = 0.00146001
# Iteration 3884, loss = 0.00145899
# Iteration 3885, loss = 0.00145797
# Iteration 3886, loss = 0.00145695
# Iteration 3887, loss = 0.00145593
# Iteration 3888, loss = 0.00145491
# Iteration 3889, loss = 0.00145389
# Iteration 3890, loss = 0.00145287
# Iteration 3891, loss = 0.00145186
# Iteration 3892, loss = 0.00145084
# Iteration 3893, loss = 0.00144983
# Iteration 3894, loss = 0.00144881
# Iteration 3895, loss = 0.00144780
# Iteration 3896, loss = 0.00144679
# Iteration 3897, loss = 0.00144578
# Iteration 3898, loss = 0.00144477
# Iteration 3899, loss = 0.00144376
# Iteration 3900, loss = 0.00144275
# Iteration 3901, loss = 0.00144174
# Iteration 3902, loss = 0.00144074
# Iteration 3903, loss = 0.00143973
# Iteration 3904, loss = 0.00143873
# Iteration 3905, loss = 0.00143772
# Iteration 3906, loss = 0.00143672
# Iteration 3907, loss = 0.00143572
# Iteration 3908, loss = 0.00143472
# Iteration 3909, loss = 0.00143372
# Iteration 3910, loss = 0.00143272
# Iteration 3911, loss = 0.00143172
# Iteration 3912, loss = 0.00143072
# Iteration 3913, loss = 0.00142973
# Iteration 3914, loss = 0.00142873
# Iteration 3915, loss = 0.00142774
# Iteration 3916, loss = 0.00142674
# Iteration 3917, loss = 0.00142575
# Iteration 3918, loss = 0.00142476
# Iteration 3919, loss = 0.00142377
# Iteration 3920, loss = 0.00142278
# Training loss did not improve more than tol=0.000001 for 10 consecutive epochs. Stopping.
# accuracy for test data: 31.48%
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        17
#            2       1.00      0.95      0.98        21
#            3       0.94      1.00      0.97        16
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %% [markdown]
# 繪製訓練曲線：訓練過程的誤差會隨著演算法的遞迴與迭代的增加，觀察其逐漸變小的趨勢。

# %%
fig = plt.figure(figsize=(6, 3))
plt.plot(clf_MLP.loss_curve_)
plt.grid(True)
plt.title('Training Loss Curve')
plt.xlabel('Iter.')
plt.ylabel('Fitting Loss')
plt.show()

# %% [markdown]
# 繪製混淆矩陣 Confusion matrix，觀察不同群組的分類表現

# %%
# Confusion matrix
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
# Confusion matrix
title = 'Testing score ={:.2f}%'.format(100*clf_MLP.score(X_test_, y_test))
disp = ConfusionMatrixDisplay.from_estimator(
        clf_MLP,
        X_test_,
        y_test,
        xticks_rotation=45, #'vertical',
        # display_labels=class_names,
        cmap=plt.cm.Blues,
        normalize='true',
        ax = ax
    )
disp.ax_.set_title(title)
# plot_confusion_matrix(clf, X_test, y_test,
#     cmap = plt.cm.Blues, normalize = 'true')  # normalize='false' to show numbers
# plt.title('Testing score ={:.2f}%'.format(100*clf.score(X_test, y_test)))
plt.show()

# %% [markdown]
# <font color=yellow>最佳組合選擇 by GridSearchCV</font>
#
# CV: Cross Validation

# %%
from sklearn.model_selection import  GridSearchCV, \
                        StratifiedShuffleSplit
from datetime import datetime

# Get the current date and time
now = datetime.now()
# Format the date and time as a string
now_str = now.strftime("%Y_%m_%d_%H_%M_%S")
results_file = 'data/results_' + now_str + '.csv'

opts = dict(tol = 1e-6, max_iter = int(1e6)) # parameters for LogisticRegression
parameters = {'solver':['lbfgs', 'newton-cg', 'sag', 'saga'], \
              'C':[0.1, 1, 10]} # parameters for GridSearchCV
# parameters = {'solver':['lbfgs', 'liblinear', 'newton-cg',\
#                         'sag','saga']}
cv = StratifiedShuffleSplit(n_splits=5, test_size=0.3, \
                            random_state=0) # 5-fold CV
grid = GridSearchCV(estimator=LogisticRegression(**opts), \
                param_grid=parameters, cv=cv, 
                scoring=['accuracy','f1_macro'], refit="accuracy")
grid.fit(X_train_, y_train)
cv_logistic = pd.DataFrame(data = grid.cv_results_)
cv_logistic.to_csv(results_file)
print(grid.best_params_)
print(grid.best_score_)
print(grid.best_estimator_)
# Out:
# {'C': 1, 'solver': 'lbfgs'}
# 0.9894736842105264
# LogisticRegression(C=1, max_iter=1000000, tol=1e-06)
